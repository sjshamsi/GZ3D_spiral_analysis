# %%
import sys
sys.path.insert(0, '/raid5/homes/sshamsi/galaxy_zoo/GZ3D_spiral_analysis/')

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

from spiral_galaxy_nocov import SpiralGalaxy
# Out:
# [INFO]: No release version set. Setting default to MPL-10
# [WARNING]: path /homes/sshamsi/sas/mangawork/manga/spectro/analysis/v3_0_1/3.0.1/dapall-v3_0_1-3.0.1.fits cannot be found. Setting dapall to None. (MarvinUserWarning)

# %%
def append_directory(path):
    file_list = []
    path_list = []
    
    for root, dirs, files in os.walk(path):
        for file in files:
            if file.endswith(".fits.gz"):
                file_list.append(file)
                
                element = root + file
                path_list.append(element)
                
    return file_list, path_list

# %%
root_path = str(np.load('/raid5/homes/sshamsi/galaxy_zoo/GZ3D_spiral_analysis/v3_file_root.npy'))

files, paths = append_directory(root_path)

# %%
count = 0

for path in paths:
    count += 1
    
    try:
        gal = SpiralGalaxy(path)
        print('Done', count, 'on the first try!')
    except:
        try:
            gal = SpiralGalaxy(path)
            print('Done', count, 'on the second try!')
        except:
            print('Owchie Wowchie', count, 'is Grouchy')
            continue
# Out:
# [WARNING]: drpall file not found. Downloading it. (MarvinUserWarning)
# Progress: 100%|██████████| 1/1 [00:10<00:00, 10.01s/files, n_files=1, n_streams=1]
# SDSS_ACCESS> Done!
# 'NoneType' object has no attribute 'name'
# Traceback (most recent call last):
#   File "<ipython-input-10-d6230dae82ce>", line 7, in <module>
#     gal = SpiralGalaxy(path)
#   File "/raid5/homes/sshamsi/galaxy_zoo/GZ3D_spiral_analysis/spiral_galaxy_nocov.py", line 18, in __init__
#     self.maps = Maps(self.mangaid)
#   File "/packages/python3.7.7/lib/python3.7/site-packages/marvin/tools/maps.py", line 100, in __init__
#     drpall=drpall, download=download)
#   File "/packages/python3.7.7/lib/python3.7/site-packages/marvin/tools/core.py", line 118, in __init__
#     download=download)
#   File "/packages/python3.7.7/lib/python3.7/site-packages/marvin/tools/mixins/mma.py", line 118, in __init__
#     self._determine_inputs(input)
# ...

# %%
len(paths)
# Out:
# 29813
