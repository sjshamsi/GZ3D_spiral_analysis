# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

from new_Galaxy import SpiralGalaxy
# Out:
# INFO: No release version set. Setting default to MPL-7

# %%
fits_path = '/raid5/homes/sshamsi/sas/mangawork/manga/sandbox/galaxyzoo3d/v1_0_0/1-620993_127_5679450.fits.gz'

# %%
gal = SpiralGalaxy(fits_path)
# Out:
# /homes/sshamsi/.local/lib/python3.5/site-packages/marvin/tools/maps.py:272: MarvinUserWarning: mismatch between file version=DR15 and object release=MPL-7. Setting object release to DR15
#   marvin.core.exceptions.MarvinUserWarning)

# %%
gal.get_arms_spaxel_mask()

# %%
spaxel_mask = gal.arms_spaxel_mask

# %%
mask_spiral = ~spaxel_mask * 2**30
mask_nonspiral = spaxel_mask * 2**30

# %%
spiral_mask = gal.hamap.mask | mask_nonspiral
nonspiral_mask = gal.hamap.mask | mask_spiral

# %%
gal.hamap.plot(mask=spiral_mask)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3615a8b208>)

# %%
gal.hamap.plot(mask=nonspiral_mask)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3615980f98>)
